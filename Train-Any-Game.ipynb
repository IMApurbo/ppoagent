# %% [markdown]
# # The main Agent Cell

# %%
import numpy as np
import tensorflow as tf
import gymnasium as gym
from tensorflow.keras import layers

class PPOAgent:
    def __init__(self, input_dim, action_dim, lr=0.0003, gamma=0.99, clip_epsilon=0.2):
        self.input_dim = input_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.clip_epsilon = clip_epsilon

        # Define models
        self.policy_model = self._build_policy_model()
        self.value_model = self._build_value_model()

        # Optimizers
        self.policy_optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
        self.value_optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    def _build_policy_model(self):
        """Builds the policy network."""
        inputs = layers.Input(shape=(self.input_dim,))
        x = layers.Dense(64, activation='relu')(inputs)
        x = layers.Dense(64, activation='relu')(x)
        outputs = layers.Dense(self.action_dim, activation='softmax')(x)
        return tf.keras.Model(inputs, outputs)

    def _build_value_model(self):
        """Builds the value network."""
        inputs = layers.Input(shape=(self.input_dim,))
        x = layers.Dense(64, activation='relu')(inputs)
        x = layers.Dense(64, activation='relu')(x)
        outputs = layers.Dense(1)(x)
        return tf.keras.Model(inputs, outputs)

    def select_action(self, state):
        """Selects an action based on the policy."""
        state = np.expand_dims(state, axis=0)
        probabilities = self.policy_model(state).numpy().flatten()
        action = np.random.choice(self.action_dim, p=probabilities)
        return action, probabilities[action]

    def train(self, states, actions, rewards, dones, old_probs):
        """Trains the PPO agent."""
        # Compute discounted rewards
        discounted_rewards = self._compute_discounted_rewards(rewards, dones)

        # Convert to tensors
        states = tf.convert_to_tensor(states, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.int32)
        old_probs = tf.convert_to_tensor(old_probs, dtype=tf.float32)
        discounted_rewards = tf.convert_to_tensor(discounted_rewards, dtype=tf.float32)

        with tf.GradientTape(persistent=True) as tape:
            # Compute current probabilities and value estimates
            logits = self.policy_model(states)
            values = tf.squeeze(self.value_model(states))
            action_masks = tf.one_hot(actions, self.action_dim)
            current_probs = tf.reduce_sum(action_masks * logits, axis=1)

            # PPO Policy Loss
            ratios = current_probs / old_probs
            advantages = discounted_rewards - values
            clipped_ratios = tf.clip_by_value(ratios, 1 - self.clip_epsilon, 1 + self.clip_epsilon)
            policy_loss = -tf.reduce_mean(tf.minimum(ratios * advantages, clipped_ratios * advantages))

            # Value Loss
            value_loss = tf.reduce_mean(tf.square(discounted_rewards - values))

            # Entropy Bonus
            entropy = -tf.reduce_mean(tf.reduce_sum(logits * tf.math.log(logits + 1e-10), axis=1))

            total_loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

        # Apply gradients
        policy_grads = tape.gradient(policy_loss, self.policy_model.trainable_variables)
        value_grads = tape.gradient(value_loss, self.value_model.trainable_variables)
        self.policy_optimizer.apply_gradients(zip(policy_grads, self.policy_model.trainable_variables))
        self.value_optimizer.apply_gradients(zip(value_grads, self.value_model.trainable_variables))

    def _compute_discounted_rewards(self, rewards, dones):
        """Computes discounted rewards."""
        discounted_rewards = []
        cumulative = 0
        for reward, done in zip(reversed(rewards), reversed(dones)):
            if done:
                cumulative = 0
            cumulative = reward + self.gamma * cumulative
            discounted_rewards.insert(0, cumulative)
        return np.array(discounted_rewards)

    def save(self, path):
# Episode 219/1000, Total Reward: 15.0
# Episode 220/1000, Total Reward: 98.0
# Episode 221/1000, Total Reward: 25.0
# Episode 222/1000, Total Reward: 31.0
# Episode 223/1000, Total Reward: 40.0
# Episode 224/1000, Total Reward: 45.0
# Episode 225/1000, Total Reward: 13.0
# Episode 226/1000, Total Reward: 63.0
# Episode 227/1000, Total Reward: 20.0
# Episode 228/1000, Total Reward: 39.0
# Episode 229/1000, Total Reward: 45.0
# Episode 230/1000, Total Reward: 20.0
# Episode 231/1000, Total Reward: 24.0
# Episode 232/1000, Total Reward: 21.0
# Episode 233/1000, Total Reward: 18.0
# Episode 234/1000, Total Reward: 61.0
# Episode 235/1000, Total Reward: 27.0
# Episode 236/1000, Total Reward: 28.0
# Episode 237/1000, Total Reward: 19.0
# Episode 238/1000, Total Reward: 46.0
# Episode 239/1000, Total Reward: 88.0
# Episode 240/1000, Total Reward: 53.0
# Episode 241/1000, Total Reward: 19.0
# Episode 242/1000, Total Reward: 38.0
# Episode 243/1000, Total Reward: 61.0
# Episode 244/1000, Total Reward: 10.0
# Episode 245/1000, Total Reward: 58.0
# Episode 246/1000, Total Reward: 32.0
# Episode 247/1000, Total Reward: 93.0
# Episode 248/1000, Total Reward: 35.0
# Episode 249/1000, Total Reward: 17.0
# Episode 250/1000, Total Reward: 15.0
# Episode 251/1000, Total Reward: 25.0
# Episode 252/1000, Total Reward: 36.0
# Episode 253/1000, Total Reward: 23.0
# Episode 254/1000, Total Reward: 28.0
# Episode 255/1000, Total Reward: 18.0
# Episode 256/1000, Total Reward: 39.0
# Episode 257/1000, Total Reward: 35.0
# Episode 258/1000, Total Reward: 40.0
# Episode 259/1000, Total Reward: 12.0
# Episode 260/1000, Total Reward: 21.0
# Episode 261/1000, Total Reward: 90.0
# Episode 262/1000, Total Reward: 127.0
# Episode 263/1000, Total Reward: 28.0
# Episode 264/1000, Total Reward: 29.0
# Episode 265/1000, Total Reward: 151.0
# Episode 266/1000, Total Reward: 24.0
# Episode 267/1000, Total Reward: 65.0
# Episode 268/1000, Total Reward: 18.0
# Episode 269/1000, Total Reward: 39.0
# Episode 270/1000, Total Reward: 42.0
# Episode 271/1000, Total Reward: 80.0
# Episode 272/1000, Total Reward: 30.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 135
#     132         total_reward += reward
#     134         if done:
# --> 135             agent.train(states, actions, rewards, dones, old_probs)
#     136             print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")
#     139 # Optionally save the model after training
#
# Cell In[2], line 80, in PPOAgent.train(self, states, actions, rewards, dones, old_probs)
#      78 value_grads = tape.gradient(value_loss, self.value_model.trainable_variables)
#      79 self.policy_optimizer.apply_gradients(zip(policy_grads, self.policy_model.trainable_variables))
# ---> 80 self.value_optimizer.apply_gradients(zip(value_grads, self.value_model.trainable_variables))
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:344, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     342 def apply_gradients(self, grads_and_vars):
#     343     grads, trainable_variables = zip(*grads_and_vars)
# --> 344     self.apply(grads, trainable_variables)
#     345     # Return iterations for compat with tf.keras.
#     346     return self._iterations
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:409, in BaseOptimizer.apply(self, grads, trainable_variables)
#     406     grads = [g if g is None else g / scale for g in grads]
#     408 # Apply gradient updates.
# --> 409 self._backend_apply_gradients(grads, trainable_variables)
#     410 # Apply variable constraints after applying gradients.
#     411 for variable in trainable_variables:
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:472, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     469     self._apply_weight_decay(trainable_variables)
#     471     # Run update step.
# --> 472     self._backend_update_step(
#     473         grads, trainable_variables, self.learning_rate
#     474     )
#     476 if self.use_ema:
#     477     self._update_model_variables_moving_average(
#     478         self._trainable_variables
#     479     )
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:120, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     118 grads_and_vars = list(zip(grads, trainable_variables))
#     119 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 120 tf.__internal__.distribute.interim.maybe_merge_call(
#     121     self._distributed_tf_update_step,
#     122     self._distribution_strategy,
#     123     grads_and_vars,
#     124     learning_rate,
#     125 )
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:134, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     131     return self.update_step(grad, var, learning_rate)
#     133 for grad, var in grads_and_vars:
# --> 134     distribution.extended.update(
#     135         var,
#     136         apply_grad_to_update_var,
#     137         args=(grad, learning_rate),
#     138         group=False,
#     139     )
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:131, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     130 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 131     return self.update_step(grad, var, learning_rate)
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/optimizers/adam.py:148, in Adam.update_step(self, gradient, variable, learning_rate)
#     143     self.assign(v_hat, ops.maximum(v_hat, v))
#     144     v = v_hat
#     145 self.assign_sub(
#     146     variable,
#     147     ops.divide(
# --> 148         ops.multiply(m, alpha), ops.add(ops.sqrt(v), self.epsilon)
#     149     ),
#     150 )
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/ops/numpy.py:168, in add(x1, x2)
#     166 if any_symbolic_tensors((x1, x2)):
#     167     return Add().symbolic_call(x1, x2)
# --> 168 return backend.numpy.add(x1, x2)
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/backend/tensorflow/sparse.py:493, in elementwise_binary_union.<locals>.wrap_elementwise_binary_union.<locals>.sparse_wrapper(x1, x2)
#     490 elif isinstance(x2, tf.IndexedSlices):
#     491     # x2 is an IndexedSlices, densify.
#     492     x2 = tf.convert_to_tensor(x2)
# --> 493 return func(x1, x2)
#
# File ~/myenv/lib/python3.12/site-packages/keras/src/backend/tensorflow/numpy.py:62, in add(x1, x2)
#      59         x2 = tf.squeeze(x2)
#      60     return tf.nn.bias_add(x1, x2, data_format=data_format)
# ---> 62 return tf.add(x1, x2)
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/tensorflow/python/ops/math_ops.py:3934, in add(x, y, name)
#    3862 @tf_export("math.add", "add")
#    3863 @dispatch.register_binary_elementwise_api
#    3864 @dispatch.add_dispatch_support
#    3865 def add(x, y, name=None):
#    3866   """Returns x + y element-wise.
#    3867
#    3868   Example usages below.
#    (...)
#    3932     name: A name for the operation (optional)
#    3933   """
# -> 3934   with ops.name_scope(name, "Add", [x]) as name:
#    3935     x = ops.convert_to_tensor(x, name="x")
#    3936     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#
# KeyboardInterrupt:

# %% [markdown]
# # Initialize Gym environment and PPO agent

# %%
env = gym.make("CartPole-v1")
input_dim = env.observation_space.shape[0]  # State dimension
action_dim = env.action_space.n  # Number of possible actions

agent = PPOAgent(input_dim=input_dim, action_dim=action_dim)

# %% [markdown]
# # Training loop

# %%
episodes = 1000
for episode in range(episodes):
    state, _ = env.reset()  # Fix: reset() now returns a tuple (state, info)
    state = np.array(state)
    done = False
    total_reward = 0
    states, actions, rewards, dones, old_probs = [], [], [], [], []

    while not done:
        action, old_prob = agent.select_action(state)
        next_state, reward, done, _, _ = env.step(action)
        
        # Collect experience
        states.append(state)
        actions.append(action)
        rewards.append(reward)
        dones.append(done)
        old_probs.append(old_prob)

        state = next_state
        total_reward += reward

        if done:
            agent.train(states, actions, rewards, dones, old_probs)
            print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")
# Out:
# Episode 1/1000, Total Reward: 379.0
# Episode 2/1000, Total Reward: 4224.0
# Episode 3/1000, Total Reward: 638.0
# Episode 4/1000, Total Reward: 938.0
# Episode 5/1000, Total Reward: 1319.0
# Episode 6/1000, Total Reward: 1144.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_109909/1455427634.py in ?()
#       7     total_reward = 0
#       8     states, actions, rewards, dones, old_probs = [], [], [], [], []
#       9
#      10     while not done:
# ---> 11         action, old_prob = agent.select_action(state)
#      12         next_state, reward, done, _, _ = env.step(action)
#      13
#      14         # Collect experience
#
# /tmp/ipykernel_109909/2414333410.py in ?(self, state)
#      37     def select_action(self, state):
#      38         """Selects an action based on the policy."""
#      39         state = np.expand_dims(state, axis=0)
# ---> 40         probabilities = self.policy_model(state).numpy().flatten()
#      41         action = np.random.choice(self.action_dim, p=probabilities)
#      42         return action, probabilities[action]
#
# ~/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/myenv/lib/python3.12/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/myenv/lib/python3.12/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/myenv/lib/python3.12/site-packages/keras/src/models/functional.py in ?(self, inputs, training, mask)
#     178             masks = tree.flatten(mask)
#     179             for x, mask in zip(inputs, masks):
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#     185         return unpack_singleton(outputs)
#
# ~/myenv/lib/python3.12/site-packages/keras/src/ops/function.py in ?(self, inputs, operation_fn, call_fn)
#     167                 op = operation_fn(node.operation)
#     168                 if call_fn is not None:
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#     174                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# ~/myenv/lib/python3.12/site-packages/keras/src/models/functional.py in ?(*args, **kwargs)
#     628             and operation._call_has_training_arg
#     629             and training is not None
#     630         ):
#     631             kwargs["training"] = training
# --> 632         return operation(*args, **kwargs)
#
# ~/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/myenv/lib/python3.12/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/myenv/lib/python3.12/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/myenv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/myenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py in ?(self, inputs, training)
#     144         x = ops.matmul(inputs, self.kernel)
#     145         if self.bias is not None:
#     146             x = ops.add(x, self.bias)
#     147         if self.activation is not None:
# --> 148             x = self.activation(x)
#     149         return x
#
# ~/myenv/lib/python3.12/site-packages/keras/src/activations/activations.py in ?(x, axis)
#     156     Args:
#     157         x: Input tensor.
#     158         axis: Integer, axis along which the softmax is applied.
#     159     """
# --> 160     output = ops.softmax(x, axis=axis)
#     161     # Cache the logits to use for crossentropy loss.
#     162     try:
#     163         output._keras_logits = x
#
# ~/myenv/lib/python3.12/site-packages/keras/src/ops/nn.py in ?(x, axis)
#     848             x, axes=list(backend.numpy.argsort([*axis_to_keep, *axis]))
#     849         )
#     850         return x
#     851     else:
# --> 852         return backend.nn.softmax(x, axis=axis)
#
# ~/myenv/lib/python3.12/site-packages/keras/src/backend/tensorflow/nn.py in ?(x, axis)
#     127         output = tf.reshape(x, [-1])
#     128         output = tf.nn.softmax(output, axis=-1)
#     129         output = tf.reshape(output, tf.shape(x))
#     130     else:
# --> 131         output = tf.nn.softmax(x, axis=axis)
#     132     output._keras_logits = logits
#     133     return output
#
# ~/myenv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/myenv/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/myenv/lib/python3.12/site-packages/tensorflow/python/ops/nn_ops.py in ?(logits, axis, name)
#    3903       dimension of `logits`.
#    3904   """
#    3905   if axis is None:
#    3906     axis = -1
# -> 3907   return _wrap_2d_function(logits, gen_nn_ops.softmax, axis, name)
#
# ~/myenv/lib/python3.12/site-packages/tensorflow/python/ops/nn_ops.py in ?(inputs, compute_op, dim, name)
#    3821   shape = inputs.get_shape()
#    3822   is_last_dim = (dim == -1) or (dim == shape.ndims - 1)
#    3823
#    3824   if is_last_dim:
# -> 3825     return compute_op(inputs, name=name)
#    3826
#    3827   dim_val = dim
#    3828   if isinstance(dim, tensor_lib.Tensor):
#
# ~/myenv/lib/python3.12/site-packages/tensorflow/python/ops/gen_nn_ops.py in ?(logits, name)
#   11999         _ctx, "Softmax", name, logits)
#   12000       return _result
#   12001     except _core._NotOkStatusException as e:
#   12002       _ops.raise_from_not_ok_status(e, name)
# > 12003     except _core._FallbackException:
#   12004       pass
#   12005     try:
#   12006       return softmax_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# # Save the model after training

# %%
agent.save("ppo_cartpole_model")

# %% [markdown]
# # Test The Model On game

# %%
import gymnasium as gym
import numpy as np
import tensorflow as tf

# Test the trained PPO agent
def test_ppo_agent(agent, env_name="CartPole-v1", episodes=10):
    # Create the environment
    env = gym.make(env_name, render_mode="human")
    
    # Loop through the test episodes
    for episode in range(episodes):
        state, _ = env.reset()  # Reset the environment and get the initial state
        state = np.array(state)
        done = False
        total_reward = 0
        
        while not done:
            # Use the trained agent to select an action
            action, _ = agent.select_action(state)
            
            # Take the action in the environment
            next_state, reward, done, _, _ = env.step(action)
            
            # Update the state
            state = next_state
            total_reward += reward
            
            # Render the environment (this can be turned off if running headless)
            env.render()

            if done:
                print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

    # Close the environment
    env.close()

# Assuming `agent` is the trained PPOAgent, use this to test the agent
test_ppo_agent(agent)
# Out:
# Episode 1/10, Total Reward: 1849.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 38
#      35     env.close()
#      37 # Assuming `agent` is the trained PPOAgent, use this to test the agent
# ---> 38 test_ppo_agent(agent)
#
# Cell In[6], line 22, in test_ppo_agent(agent, env_name, episodes)
#      19 action, _ = agent.select_action(state)
#      21 # Take the action in the environment
# ---> 22 next_state, reward, done, _, _ = env.step(action)
#      24 # Update the state
#      25 state = next_state
#
# File ~/myenv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/myenv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/myenv/lib/python3.12/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File ~/myenv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/myenv/lib/python3.12/site-packages/gymnasium/envs/classic_control/cartpole.py:223, in CartPoleEnv.step(self, action)
#     220     reward = -1.0 if self._sutton_barto_reward else 0.0
#     222 if self.render_mode == "human":
# --> 223     self.render()
#     225 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     226 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/myenv/lib/python3.12/site-packages/gymnasium/envs/classic_control/cartpole.py:337, in CartPoleEnv.render(self)
#     335 if self.render_mode == "human":
#     336     pygame.event.pump()
# --> 337     self.clock.tick(self.metadata["render_fps"])
#     338     pygame.display.flip()
#     340 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
